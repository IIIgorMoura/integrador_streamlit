# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_prop_23 = pd.read_excel('./DBs/df_srag_populacao_PRINCIPAIS_23.xlsx')
df_prop_24 = pd.read_excel('./DBs/df_srag_populacao_PRINCIPAIS_24.xlsx')

# %% [markdown]
# # Organização do Maior para o Menor

# %%
df_prop_23_sorted = df_prop_23.sort_values(by='PROPORCAO', ascending=False).reset_index(drop=True)

df_prop_24_sorted = df_prop_24.sort_values(by='PROPORCAO', ascending=False).reset_index(drop=True)
df_prop_24_sorted.head(30)
# Out:
#                    CIDADE  QUANTIDADE DE CASOS   POPULACAO   PROPORCAO  \
# 0      SAO CAETANO DO SUL                 1389    159053.0  873.293808
# 1                     POA                  474    123845.0  382.736485
# 2                  SANTOS                 1601    433656.0  369.186636
# 3          RIBEIRAO PIRES                  172    111341.0  154.480380
# 4   SAO BERNARDO DO CAMPO                 1301    864542.0  150.484303
# 5               SAO PAULO                18625  12396372.0  150.245572
# 6            PRAIA GRANDE                  256    319718.0   80.070562
# 7         MOGI DAS CRUZES                  325    453296.0   71.697081
# 8                 GUARUJA                  173    312251.0   55.404146
# 9             SANTO ANDRE                  367    844366.0   43.464564
# 10                 SUZANO                  126    299049.0   42.133563
# 11                CUBATAO                   50    128251.0   38.986051
# ...

# %%
df_prop_23_sorted = df_prop_23_sorted.iloc[:20]
display(df_prop_23_sorted)

df_prop_24_sorted = df_prop_24_sorted.iloc[:20]
display(df_prop_24_sorted)
# Out:
#                    CIDADE  QUANTIDADE DE CASOS   POPULACAO    PROPORCAO  \
# 0      SAO CAETANO DO SUL                 1731    159053.0  1088.316473
# 1                  SANTOS                 2182    433656.0   503.163798
# 2                     POA                  282    123845.0   227.703985
# 3               SAO PAULO                22481  12396372.0   181.351447
# 4          RIBEIRAO PIRES                  138    111341.0   123.943561
# 5   SAO BERNARDO DO CAMPO                  977    864542.0   113.007812
# 6                 GUARUJA                  217    312251.0    69.495374
# 7         MOGI DAS CRUZES                  302    453296.0    66.623134
# 8             SANTO ANDRE                  535    844366.0    63.361149
# 9                  SUZANO                  164    299049.0    54.840511
# 10               ITANHAEM                   81    158696.0    51.040984
# 11                DIADEMA                  195    433589.0    44.973466
# ...
